# %% [markdown]
# ![QMUL](Images/QMUL-logo.jpg)
#
# # Statistics for Biologists
#
#
# ## Probability distributions - practical

# %% [markdown]
# In this practical we'll be using the dataset in the file `measles.csv` available in the `Data` folder.
# This is a dataset from a famous study which demonstrated the very strong link between population size and infectious disease epidemiology. For 19 islands from the Atlantic and Pacific Oceans we have data for the population size in 1956 and the percentage of months during the study period when measles was reported as being present on the islands.

# %% [markdown]
# #### Task 1
# Read the file in __R__ using the `read.csv()` function. Explore the first lines of the file and the stored variables using `head()` and `str()` functions. Finally, plot a histogram of each numerical variable using the `breaks=` argument to change the number of bins.

# %%
# ...

# %% [markdown]
# #### Task 2
# Using the `boxplot()` function, generate boxplots showing how population size are related to region.
# This can be achieved by these two different approaches.
#
#
# * `boxplot(measles$Population[measles$Region=="Atlantic"],
# measles$Population[measles$Region=="Pacific"], ylab="Population size", xlab=c("Atlantic", "Pacific"))`
#
#
# * `boxplot(formula=Population~Region, data=measles)`
#
# Try to understand what they do and look up the help page for the `boxplot()` function.

# %%
# ...

# %% [markdown]
# #### Task 3
#
# Draw scatter plots of the percent of months with measles reported against _susceptibles input_ and _population size_. What do you conclude?
#
# Finally, and optionally, you can make all your plots visually more appealing by exploring all plotting options available.
#
# You can change your plot parameters to change the look of the plot in the arguments for the `plot()` function. There's a good brief guide [here](http://www.statmethods.net/advgraphs/parameters.html). Try changing the plot symbol (e.g. `pch=16` for a filled circle), the colour (`col="red"` or `col="steelblue"`).
# Also, `xlab="Some text"` will set the x-axis label and `ylab="Some more text"` the label for the y-axis, and `main="Title"` will give our graph an overall title.
#
# Finally, you can use the `points()` function to overwrite the points for a particular region with a different plot symbol or a different colour. You need to specify the points using a subscript (e.g. `[Region=="Pacific"]`) for both the variables used in the plot function.

# %%
# ...

# %% [markdown]
# #### Task 4
#
# Assume that the distribution of population sizes can be "modelled" by an exponential distribution. We will learn what "modelling" means more in detail the next days. So far, assume that the observed distribution has a similar distribution than the "model".
#
# Specifically, assume that the population size in 100,000 units is modelled by an exponential distribution with rate equal to 0.7. Show that this modelling is valid by visualisation.
#
# Calculate the probability that a newly sampled population will have size larger than 300,000 under this modelling assumptions.

# %%
# ...
